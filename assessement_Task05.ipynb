# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/content/takehome_user_engagement.csv")

# %%
df
# Out:
#                  time_stamp  user_id  visited
# 0       2014-04-22 03:53:30        1        1
# 1       2013-11-15 03:45:04        2        1
# 2       2013-11-29 03:45:04        2        1
# 3       2013-12-09 03:45:04        2        1
# 4       2013-12-25 03:45:04        2        1
# ...                     ...      ...      ...
# 207912  2013-09-06 06:14:15    11996        1
# 207913  2013-01-15 18:28:37    11997        1
# 207914  2014-04-27 12:45:16    11998        1
# 207915  2012-06-02 11:55:59    11999        1
# 207916  2014-01-26 08:57:12    12000        1
#
# [207917 rows x 3 columns]

# %%
df.dtypes
# Out:
# time_stamp    object
# user_id        int64
# visited        int64
# dtype: object

# %%
c=df["user_id"].value_counts()
c
# Out:
# 3623     606
# 906      600
# 1811     593
# 7590     590
# 8068     585
#         ...
# 4699       1
# 4698       1
# 4697       1
# 4696       1
# 12000      1
# Name: user_id, Length: 8823, dtype: int64

# %%
c.loc[c.values>=3]
# Out:
# 3623     606
# 906      600
# 1811     593
# 7590     590
# 8068     585
#         ...
# 11778      3
# 241        3
# 4187       3
# 8109       3
# 8564       3
# Name: user_id, Length: 2248, dtype: int64

# %%
c.index
# Out:
# Int64Index([ 3623,   906,  1811,  7590,  8068,  9402,  4022,  3269,  9312,
#              7210,
#             ...
#              4708,  4706,  4705,  4704,  4700,  4699,  4698,  4697,  4696,
#             12000],
#            dtype='int64', length=8823)

# %%
df[(df["user_id"] == 3623)]
# Out:
#                 time_stamp  user_id  visited
# 62717  2012-06-27 14:34:33     3623        1
# 62718  2012-07-01 14:34:33     3623        1
# 62719  2012-07-02 14:34:33     3623        1
# 62720  2012-07-04 14:34:33     3623        1
# 62721  2012-07-08 14:34:33     3623        1
# ...                    ...      ...      ...
# 63318  2014-05-23 14:34:33     3623        1
# 63319  2014-05-24 14:34:33     3623        1
# 63320  2014-05-25 14:34:33     3623        1
# 63321  2014-05-26 14:34:33     3623        1
# 63322  2014-05-27 14:34:33     3623        1
#
# [606 rows x 3 columns]

# %%
x=[]
for i in c.index:
  d=df[(df["user_id"] == i)]
  if len(d.set_index(d.time_stamp).resample("7D"))>2:
    x.append(i)
print(x)
# Out:
# [3623, 906, 1811, 7590, 8068, 9402, 4022, 3269, 9312, 7210, 8029, 2474, 2658, 8280, 69, 5297, 4019, 9083, 2519, 4263, 3226, 10599, 6312, 10953, 2316, 8426, 603, 2078, 445, 7536, 8768, 11428, 6171, 5609, 7120, 9281, 10734, 8381, 5939, 7572, 5386, 2622, 11300, 1822, 2771, 6064, 4282, 8912, 6405, 5151, 5682, 4402, 5101, 9728, 2300, 1769, 9450, 9958, 4965, 5240, 2568, 8721, 9434, 2620, 4924, 754, 5861, 9691, 4143, 6757, 7511, 728, 6204, 10524, 8553, 6282, 6909, 7375, 4186, 10320, 9724, 9325, 10258, 11267, 8297, 9582, 10352, 4489, 3066, 605, 7431, 4803, 9286, 11083, 9042, 5965, 2739, 11688, 9601, 10791, 1155, 5415, 4234, 9540, 8310, 4713, 10656, 4181, 5057, 2539, 6978, 4934, 4742, 3411, 7153, 6284, 1202, 1865, 4745, 3957, 3160, 3824, 9771, 7926, 1027, 3175, 4835, 63, 9400, 8399, 5507, 9645, 783, 2447, 10630, 4837, 10602, 4785, 9694, 3556, 4248, 7107, 8243, 2333, 7899, 3960, 1434, 4497, 8259, 5281, 6370, 42, 4612, 11015, 11195, 8945, 9901, 3217, 6464, 3139, 10307, 2723, 4145, 7688, 4335, 2
# ...

# %%
print(len(x))
# Out:
# 2364

# %%
d=df[(df["user_id"] == 3623)]
d
# Out:
#                time_stamp  user_id  visited
# 62717 2012-06-27 14:34:33     3623        1
# 62718 2012-07-01 14:34:33     3623        1
# 62719 2012-07-02 14:34:33     3623        1
# 62720 2012-07-04 14:34:33     3623        1
# 62721 2012-07-08 14:34:33     3623        1
# ...                   ...      ...      ...
# 63318 2014-05-23 14:34:33     3623        1
# 63319 2014-05-24 14:34:33     3623        1
# 63320 2014-05-25 14:34:33     3623        1
# 63321 2014-05-26 14:34:33     3623        1
# 63322 2014-05-27 14:34:33     3623        1
#
# [606 rows x 3 columns]

# %%
d.loc[:,'time_stamp']
# Out:
# 62717   2012-06-27 14:34:33
# 62718   2012-07-01 14:34:33
# 62719   2012-07-02 14:34:33
# 62720   2012-07-04 14:34:33
# 62721   2012-07-08 14:34:33
#                 ...
# 63318   2014-05-23 14:34:33
# 63319   2014-05-24 14:34:33
# 63320   2014-05-25 14:34:33
# 63321   2014-05-26 14:34:33
# 63322   2014-05-27 14:34:33
# Name: time_stamp, Length: 606, dtype: datetime64[ns]

# %%
len(d.set_index(d.time_stamp).resample("7D"))
# Out:
# 100

# %%
df.time_stamp=pd.to_datetime(df["time_stamp"])

# %%
df.dtypes
# Out:
# time_stamp    datetime64[ns]
# user_id                int64
# visited                int64
# dtype: object

# %%
c.index
# Out:
# Int64Index([ 3623,   906,  1811,  7590,  8068,  9402,  4022,  3269,  9312,
#              7210,
#             ...
#              4708,  4706,  4705,  4704,  4700,  4699,  4698,  4697,  4696,
#             12000],
#            dtype='int64', length=8823)

# %%
df2=pd.read_csv('/content/takehome_users.csv', encoding_errors='ignore')

# %%
df2
# Out:
#        object_id        creation_time               name  \
# 0              1  2014-04-22 03:53:30     Clausen August
# 1              2  2013-11-15 03:45:04      Poole Matthew
# 2              3  2013-03-19 23:14:52  Bottrill Mitchell
# 3              4  2013-05-21 08:09:28    Clausen Nicklas
# 4              5  2013-01-17 10:14:20          Raw Grace
# ...          ...                  ...                ...
# 11995      11996  2013-09-06 06:14:15       Meier Sophia
# 11996      11997  2013-01-10 18:28:37      Fisher Amelie
# 11997      11998  2014-04-27 12:45:16        Haynes Jake
# 11998      11999  2012-05-31 11:55:59       Faber Annett
# 11999      12000  2014-01-26 08:57:12          Lima Thas
#
#                             email     creation_source  \
# 0        AugustCClausen@yahoo.com        GUEST_INVITE
# 1          MatthewPoole@gustr.com          ORG_INVITE
# 2      MitchellBottrill@gustr.com          ORG_INVITE
# 3       NicklasSClausen@yahoo.com        GUEST_INVITE
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12000 entries, 0 to 11999
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   object_id                   12000 non-null  int64
#  1   creation_time               12000 non-null  object
#  2   name                        12000 non-null  object
#  3   email                       12000 non-null  object
#  4   creation_source             12000 non-null  object
#  5   last_session_creation_time  8823 non-null   float64
#  6   opted_in_to_mailing_list    12000 non-null  int64
#  7   enabled_for_marketing_drip  12000 non-null  int64
#  8   org_id                      12000 non-null  int64
#  9   invited_by_user_id          6417 non-null   float64
# dtypes: float64(2), int64(4), object(4)
# memory usage: 937.6+ KB

# %%
fig, axes=plt.subplots(ncols=2,figsize=(20,5))
sns.countplot(x='creation_source',ax=axes[0],data=df2)

# %%
sns.countplot(x="creation_source",hue="creation_source", data=df2)

# %%
fig, axs = plt.subplots(nrows=1)
fig.set_size_inches(10, 10);
sns.countplot(x="creation_source",hue="creation_source", data=df2);

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df2.email.unique()
# Out:
# array(['AugustCClausen@yahoo.com', 'MatthewPoole@gustr.com',
#        'MitchellBottrill@gustr.com', ..., 'JakeHaynes@cuvox.de',
#        'mhaerzxp@iuxiw.com', 'ThaisMeloLima@hotmail.com'], dtype=object)

# %%
def mail(s):
    return s.rsplit(sep="@", maxsplit=-1)[1]

# %%
df2['unique_mail'] = df2['email'].apply(mail)

# %%
df2
# Out:
#        object_id        creation_time               name  \
# 0              1  2014-04-22 03:53:30     Clausen August
# 1              2  2013-11-15 03:45:04      Poole Matthew
# 2              3  2013-03-19 23:14:52  Bottrill Mitchell
# 3              4  2013-05-21 08:09:28    Clausen Nicklas
# 4              5  2013-01-17 10:14:20          Raw Grace
# ...          ...                  ...                ...
# 11995      11996  2013-09-06 06:14:15       Meier Sophia
# 11996      11997  2013-01-10 18:28:37      Fisher Amelie
# 11997      11998  2014-04-27 12:45:16        Haynes Jake
# 11998      11999  2012-05-31 11:55:59       Faber Annett
# 11999      12000  2014-01-26 08:57:12          Lima Thas
#
#                             email     creation_source  \
# 0        AugustCClausen@yahoo.com        GUEST_INVITE
# 1          MatthewPoole@gustr.com          ORG_INVITE
# 2      MitchellBottrill@gustr.com          ORG_INVITE
# 3       NicklasSClausen@yahoo.com        GUEST_INVITE
# ...

# %%
len(df2.unique_mail.unique())
# Out:
# 1184

# %%
df2.unique_mail.max()
# Out:
# 'zwmry.com'

# %%
df2.unique_mail.min()
# Out:
# 'abdnf.com'

# %%
df2
# Out:
#        object_id        creation_time               name  \
# 0              1  2014-04-22 03:53:30     Clausen August
# 1              2  2013-11-15 03:45:04      Poole Matthew
# 2              3  2013-03-19 23:14:52  Bottrill Mitchell
# 3              4  2013-05-21 08:09:28    Clausen Nicklas
# 4              5  2013-01-17 10:14:20          Raw Grace
# ...          ...                  ...                ...
# 11995      11996  2013-09-06 06:14:15       Meier Sophia
# 11996      11997  2013-01-10 18:28:37      Fisher Amelie
# 11997      11998  2014-04-27 12:45:16        Haynes Jake
# 11998      11999  2012-05-31 11:55:59       Faber Annett
# 11999      12000  2014-01-26 08:57:12          Lima Thas
#
#                             email     creation_source  \
# 0        AugustCClausen@yahoo.com        GUEST_INVITE
# 1          MatthewPoole@gustr.com          ORG_INVITE
# 2      MitchellBottrill@gustr.com          ORG_INVITE
# 3       NicklasSClausen@yahoo.com        GUEST_INVITE
# ...

# %%
df2['creation_time'] = df2['creation_time'].apply(pd.Timestamp)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12000 entries, 0 to 11999
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   object_id                   12000 non-null  int64
#  1   creation_time               12000 non-null  datetime64[ns]
#  2   name                        12000 non-null  object
#  3   email                       12000 non-null  object
#  4   creation_source             12000 non-null  object
#  5   last_session_creation_time  8823 non-null   float64
#  6   opted_in_to_mailing_list    12000 non-null  int64
#  7   enabled_for_marketing_drip  12000 non-null  int64
#  8   org_id                      12000 non-null  int64
#  9   invited_by_user_id          6417 non-null   float64
#  10  unique_mail                 12000 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(4), object(4)
# memory usage: 1.0+ MB

# %%
df2['date'] = df2['creation_time'].apply(lambda x:x.dayofweek)

# %%
df2
# Out:
#        object_id       creation_time               name  \
# 0              1 2014-04-22 03:53:30     Clausen August
# 1              2 2013-11-15 03:45:04      Poole Matthew
# 2              3 2013-03-19 23:14:52  Bottrill Mitchell
# 3              4 2013-05-21 08:09:28    Clausen Nicklas
# 4              5 2013-01-17 10:14:20          Raw Grace
# ...          ...                 ...                ...
# 11995      11996 2013-09-06 06:14:15       Meier Sophia
# 11996      11997 2013-01-10 18:28:37      Fisher Amelie
# 11997      11998 2014-04-27 12:45:16        Haynes Jake
# 11998      11999 2012-05-31 11:55:59       Faber Annett
# 11999      12000 2014-01-26 08:57:12          Lima Thas
#
#                             email     creation_source  \
# 0        AugustCClausen@yahoo.com        GUEST_INVITE
# 1          MatthewPoole@gustr.com          ORG_INVITE
# 2      MitchellBottrill@gustr.com          ORG_INVITE
# 3       NicklasSClausen@yahoo.com        GUEST_INVITE
# ...

# %%
df2['month'] = df2['creation_time'].apply(lambda x:x.month)

# %%
sns.countplot(x='month',data=df2)

# %%
sns.countplot(x='date',data=df2)

# %%
df2['year'] = df2['creation_time'].apply(lambda x:x.year)

# %%
sns.countplot(x='year',data=df2)

# %%
df2.drop_duplicates()
# Out:
#        object_id       creation_time               name  \
# 0              1 2014-04-22 03:53:30     Clausen August
# 1              2 2013-11-15 03:45:04      Poole Matthew
# 2              3 2013-03-19 23:14:52  Bottrill Mitchell
# 3              4 2013-05-21 08:09:28    Clausen Nicklas
# 4              5 2013-01-17 10:14:20          Raw Grace
# ...          ...                 ...                ...
# 11995      11996 2013-09-06 06:14:15       Meier Sophia
# 11996      11997 2013-01-10 18:28:37      Fisher Amelie
# 11997      11998 2014-04-27 12:45:16        Haynes Jake
# 11998      11999 2012-05-31 11:55:59       Faber Annett
# 11999      12000 2014-01-26 08:57:12          Lima Thas
#
#                             email     creation_source  \
# 0        AugustCClausen@yahoo.com        GUEST_INVITE
# 1          MatthewPoole@gustr.com          ORG_INVITE
# 2      MitchellBottrill@gustr.com          ORG_INVITE
# 3       NicklasSClausen@yahoo.com        GUEST_INVITE
# ...

# %%
df2.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 11995    False
# 11996    False
# 11997    False
# 11998    False
# 11999    False
# Length: 12000, dtype: bool

# %%
df2.name.unique().max()
# Out:
# 'stergaard Torben'

# %%
df2[df2.loc[:,"name"]=="stergaard Torben"]
# Out:
#       object_id       creation_time              name  \
# 8117       8118 2014-02-20 15:01:21  stergaard Torben
#
#                                 email    creation_source  \
# 8117  TorbenMstergaard@jourrapide.com  PERSONAL_PROJECTS
#
#       last_session_creation_time  opted_in_to_mailing_list  \
# 8117                         NaN                         0
#
#       enabled_for_marketing_drip  org_id  invited_by_user_id     unique_mail  \
# 8117                           0      32                 NaN  jourrapide.com
#
#       date  month  year
# 8117     3      2  2014

# %%
df2.head()
# Out:
#    object_id       creation_time               name  \
# 0          1 2014-04-22 03:53:30     Clausen August
# 1          2 2013-11-15 03:45:04      Poole Matthew
# 2          3 2013-03-19 23:14:52  Bottrill Mitchell
# 3          4 2013-05-21 08:09:28    Clausen Nicklas
# 4          5 2013-01-17 10:14:20          Raw Grace
#
#                         email creation_source  last_session_creation_time  \
# 0    AugustCClausen@yahoo.com    GUEST_INVITE                1.398139e+09
# 1      MatthewPoole@gustr.com      ORG_INVITE                1.396238e+09
# 2  MitchellBottrill@gustr.com      ORG_INVITE                1.363735e+09
# 3   NicklasSClausen@yahoo.com    GUEST_INVITE                1.369210e+09
# 4          GraceRaw@yahoo.com    GUEST_INVITE                1.358850e+09
#
#    opted_in_to_mailing_list  enabled_for_marketing_drip  org_id  \
# 0                         1                           0      11
# 1                         0                           0       1
# ...

# %%
fig, axes=plt.subplots(nrows=2,figsize=(10,10))
sns.countplot(x='opted_in_to_mailing_list',ax=axes[0],data=df2)
sns.countplot(x='creation_source', hue='opted_in_to_mailing_list',ax=axes[1], data=df2);
plt.xticks(rotation=45)
# Out:
# (array([0, 1, 2, 3, 4]), <a list of 5 Text major ticklabel objects>)

# %%
fig, axes=plt.subplots(nrows=2,figsize=(10,10))
sns.countplot(x='enabled_for_marketing_drip',ax=axes[0],data=df2)
sns.countplot(x='creation_source', hue='enabled_for_marketing_drip',ax=axes[1], data=df2);
plt.xticks(rotation=45)
# Out:
# (array([0, 1, 2, 3, 4]), <a list of 5 Text major ticklabel objects>)

# %%
fig, axes=plt.subplots(nrows=1,figsize=(50,10))
sns.countplot(x='org_id',data=df2)

# %%
df2.org_id.unique()
# Out:
# array([ 11,   1,  94, 193, 197,  37,  74, 302, 318,  69, 130, 254,   0,
#        175, 211,   2,  58,  54,   7,   6, 123,  81,  56, 134,  92, 251,
#        283,  98, 401,  33,  59, 109, 276, 208, 332,  64, 235,  63,  14,
#          4, 127,  32, 224, 304,  61,  51, 229,  88, 325, 150, 347, 203,
#         21, 409, 215, 141,   5, 107, 184, 310, 367, 389,  89, 242,  68,
#         16,  49, 185,  91, 172,   8,  43, 249,  26, 139,  70,  10, 252,
#         53, 119,   3, 196, 335, 375, 303, 307,  25, 370,  83,  27, 306,
#        118, 295,  19, 301, 100, 112, 263,  39,  12,  86, 402,  42, 103,
#        373, 268,  30, 406,  48, 313,   9, 138, 261,  35, 264,  95,  55,
#         60, 234,  28, 410, 170, 374,  15,  17, 364,  62, 244, 342, 225,
#        121, 255, 411, 217, 165, 415, 104, 329, 278, 116, 151, 290, 200,
#        187, 122, 353, 135, 328,  36,  13, 341, 349, 198, 153, 108,  77,
#        142, 275, 176,  87, 191, 102, 245, 154, 218, 385,  76, 321, 159,
# ...

# %%
df2
# Out:
#        object_id       creation_time               name  \
# 0              1 2014-04-22 03:53:30     Clausen August
# 1              2 2013-11-15 03:45:04      Poole Matthew
# 2              3 2013-03-19 23:14:52  Bottrill Mitchell
# 3              4 2013-05-21 08:09:28    Clausen Nicklas
# 4              5 2013-01-17 10:14:20          Raw Grace
# ...          ...                 ...                ...
# 11995      11996 2013-09-06 06:14:15       Meier Sophia
# 11996      11997 2013-01-10 18:28:37      Fisher Amelie
# 11997      11998 2014-04-27 12:45:16        Haynes Jake
# 11998      11999 2012-05-31 11:55:59       Faber Annett
# 11999      12000 2014-01-26 08:57:12          Lima Thas
#
#                             email     creation_source  \
# 0        AugustCClausen@yahoo.com        GUEST_INVITE
# 1          MatthewPoole@gustr.com          ORG_INVITE
# 2      MitchellBottrill@gustr.com          ORG_INVITE
# 3       NicklasSClausen@yahoo.com        GUEST_INVITE
# ...

# %%
fig, axes=plt.subplots(nrows=1,figsize=(50,10))
sns.countplot(x='invited_by_user_id',data=df2)

# %%
len(df2.invited_by_user_id.unique())
# Out:
# 2565

# %%
df1
# Out:
#                  time_stamp  user_id  visited
# 0       2014-04-22 03:53:30        1        1
# 1       2013-11-15 03:45:04        2        1
# 2       2013-11-29 03:45:04        2        1
# 3       2013-12-09 03:45:04        2        1
# 4       2013-12-25 03:45:04        2        1
# ...                     ...      ...      ...
# 207912  2013-09-06 06:14:15    11996        1
# 207913  2013-01-15 18:28:37    11997        1
# 207914  2014-04-27 12:45:16    11998        1
# 207915  2012-06-02 11:55:59    11999        1
# 207916  2014-01-26 08:57:12    12000        1
#
# [207917 rows x 3 columns]

# %%
df1.sort_values(by="user_id")
# Out:
#                  time_stamp  user_id  visited
# 0       2014-04-22 03:53:30        1        1
# 14      2014-03-31 03:45:04        2        1
# 13      2014-03-13 03:45:04        2        1
# 12      2014-03-09 03:45:04        2        1
# 11      2014-02-16 03:45:04        2        1
# ...                     ...      ...      ...
# 207912  2013-09-06 06:14:15    11996        1
# 207913  2013-01-15 18:28:37    11997        1
# 207914  2014-04-27 12:45:16    11998        1
# 207915  2012-06-02 11:55:59    11999        1
# 207916  2014-01-26 08:57:12    12000        1
#
# [207917 rows x 3 columns]

# %%
df1.user_id.unique().min()
# Out:
# 1

# %%
df1.user_id.describe()
# Out:
# count    207917.000000
# mean       5913.314197
# std        3394.941674
# min           1.000000
# 25%        3087.000000
# 50%        5682.000000
# 75%        8944.000000
# max       12000.000000
# Name: user_id, dtype: float64

# %%
fig, axes=plt.subplots(nrows=1,figsize=(50,10))
sns.countplot(x='user_id',data=df1)
# Out:
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x7f27aa4ca680> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in post_execute()
#     107             def post_execute():
#     108                 if matplotlib.is_interactive():
# --> 109                     draw_all()
#     110
#     111             # IPython >= 2
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/_pylab_helpers.py in draw_all(cls, force)
#     125         for f_mgr in cls.get_all_fig_managers():
#     126             if force or f_mgr.canvas.figure.stale:
# --> 127                 f_mgr.canvas.draw_idle()
#     128
#     129 atexit.register(Gcf.destroy_all)
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/backend_bases.py in draw_idle(self, *args, **kwargs)
# ...

# %%
type(df1.user_id)
# Out:
# pandas.core.series.Series

# %%
import numpy as np
